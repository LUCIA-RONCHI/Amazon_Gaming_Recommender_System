# %% [markdown]
# ## Loading data and necessary libraries

# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import NMF

# %%
# Read data
data = pd.read_csv("merged_file.csv", index_col = 0)

# %%
# Explore shape
data.shape
# Out:
# (497577, 20)

# %%
# Explore first rows
data.head()
# Out:
#    reviewID  overall  verified  reviewTime      reviewerID   productID  \
# 0         0        5      True  2015-10-17  A1HP7NVNPFMA4N  0700026657
# 1         1        4     False  2015-07-27  A1JGAP0185YJI6  0700026657
# 2         2        3      True  2015-02-23  A1YJWEXHQBWK2B  0700026657
# 3         3        2      True  2015-02-20  A2204E1TH211HT  0700026657
# 4         4        5      True  2014-12-25  A2RF5B5H74JLPE  0700026657
#
#                                           reviewText  \
# 0  This game is a bit hard to get the hang of, bu...
# 1  I played it a while but it was alright. The st...
# 2                                           ok game.
# 3  found the game a bit too complicated, not what...
# 4  great game, I love it and have played it since...
#
#                                        summary vote style  \
# 0                  but when you do it's great.    0   NaN
# 1  But in spite of that it was fun, I liked it    0   NaN
# 2                                  Three Stars    0   NaN
# 3                                    Two Stars    0   NaN
# 4                               love this game    0   NaN
#
#                          category      title    brand  \
# 0  ['Video Games', 'PC', 'Games']  Anno 2070  Ubisoft
# 1  ['Video Games', 'PC', 'Games']  Anno 2070  Ubisoft
# 2  ['Video Games', 'PC', 'Games']  Anno 2070  Ubisoft
# 3  ['Video Games', 'PC', 'Games']  Anno 2070  Ubisoft
# 4  ['Video Games', 'PC', 'Games']  Anno 2070  Ubisoft
#
#                                                 rank     main_cat  \
# 0  >#30,230 in Video Games (See Top 100 in Video ...  Video Games
# 1  >#30,230 in Video Games (See Top 100 in Video ...  Video Games
# 2  >#30,230 in Video Games (See Top 100 in Video ...  Video Games
# 3  >#30,230 in Video Games (See Top 100 in Video ...  Video Games
# 4  >#30,230 in Video Games (See Top 100 in Video ...  Video Games
#
#                                          description also_buy  \
# 0  ['ANNO 2070BRAND NEW - IN STOCKDVD Rom Softwar...      NaN
# 1  ['ANNO 2070BRAND NEW - IN STOCKDVD Rom Softwar...      NaN
# 2  ['ANNO 2070BRAND NEW - IN STOCKDVD Rom Softwar...      NaN
# 3  ['ANNO 2070BRAND NEW - IN STOCKDVD Rom Softwar...      NaN
# 4  ['ANNO 2070BRAND NEW - IN STOCKDVD Rom Softwar...      NaN
#
#                                            also_view  \
# 0  ['B013F0IP1C', 'B00JDP1AWU', 'B00XR3YC2E', 'B0...
# 1  ['B013F0IP1C', 'B00JDP1AWU', 'B00XR3YC2E', 'B0...
# 2  ['B013F0IP1C', 'B00JDP1AWU', 'B00XR3YC2E', 'B0...
# 3  ['B013F0IP1C', 'B00JDP1AWU', 'B00XR3YC2E', 'B0...
# 4  ['B013F0IP1C', 'B00JDP1AWU', 'B00XR3YC2E', 'B0...
#
#                                              feature  numberOfReviews
# 0  ['A new era: while adhering to the fundamental...               13
# 1  ['A new era: while adhering to the fundamental...               13
# 2  ['A new era: while adhering to the fundamental...               13
# 3  ['A new era: while adhering to the fundamental...               13
# 4  ['A new era: while adhering to the fundamental...               13

# %%
# Unique reviewerIDs (%)
len(data["reviewerID"].unique())/len(data)*100
# Out:
# 11.098382762868862

# %% [markdown]
# ## Constructing the Matrix

# %%
# Pivot table to create the matrix
ratings_matrix = data.pivot_table(index = 'reviewerID', columns = 'productID', values = 'overall', aggfunc = "mean", fill_value = 0)

# %%
# Explore first rows
ratings_matrix.head()
# Out:
# productID             0700026398  0700026657  0700099867  0804161380  \
# reviewerID
# A0059486XI1Z0P98KP35           0           0           0           0
# A0220159ZRNBTRKLG08H           0           0           0           0
# A0266076X6KPZ6CCHGVS           0           0           0           0
# A0277912HT4JSJKVSL3E           0           0           0           0
# A02836981FYG9912C66F           0           0           0           0
#
# productID             3828770193  6050036071  7293000936  7544256944  \
# reviewerID
# A0059486XI1Z0P98KP35           0           0           0           0
# A0220159ZRNBTRKLG08H           0           0           0           0
# A0266076X6KPZ6CCHGVS           0           0           0           0
# A0277912HT4JSJKVSL3E           0           0           0           0
# A02836981FYG9912C66F           0           0           0           0
#
# productID             8176503290  8565000168  ...  B01HD1B76O  B01HD2TECW  \
# reviewerID                                    ...
# A0059486XI1Z0P98KP35           0           0  ...           0           0
# A0220159ZRNBTRKLG08H           0           0  ...           0           0
# A0266076X6KPZ6CCHGVS           0           0  ...           0           0
# A0277912HT4JSJKVSL3E           0           0  ...           0           0
# A02836981FYG9912C66F           0           0  ...           0           0
#
# productID             B01HDJFJKG  B01HDJFJLK  B01HDJFJOM  B01HFRICLE  \
# reviewerID
# A0059486XI1Z0P98KP35           0           0           0           0
# A0220159ZRNBTRKLG08H           0           0           0           0
# A0266076X6KPZ6CCHGVS           0           0           0           0
# A0277912HT4JSJKVSL3E           0           0           0           0
# A02836981FYG9912C66F           0           0           0           0
#
# productID             B01HGPUTCA  B01HH6JEOC  B01HIZF7XE  B01HIZGKOE
# reviewerID
# A0059486XI1Z0P98KP35           0           0           0           0
# A0220159ZRNBTRKLG08H           0           0           0           0
# A0266076X6KPZ6CCHGVS           0           0           0           0
# A0277912HT4JSJKVSL3E           0           0           0           0
# A02836981FYG9912C66F           0           0           0           0
#
# [5 rows x 17408 columns]

# %%
# Explore shape of user-item matrix
ratings_matrix.shape
# Out:
# (55223, 17408)

# %%
# Unique users
print(len(data["reviewerID"].unique()))
# Unique products
print(len(data["productID"].unique()))
# Out:
# 55223
# 17408

# %%
# Check for an example
data.groupby(["reviewerID", "productID"]).count()["overall"]
# Out:
# reviewerID            productID
# A0059486XI1Z0P98KP35  B00024W1U6    1
#                       B000WE8JES    2
#                       B00SUUTSA0    1
#                       B012JMS4W2    1
# A0220159ZRNBTRKLG08H  B000084318    1
#                                    ..
# AZZTOUKVTUMVM         B0012N1Z8A    2
#                       B001CP5WXC    1
#                       B0094X2066    1
#                       B00BU3ZLJQ    1
#                       B00CXTX2YW    1
# Name: overall, Length: 473427, dtype: int64

# %%
# Let's look at the matrix for user A0059486XI1Z0P98KP35, product B000WE8JES: ORIGINAL DATA
data.loc[(data["reviewerID"] == "A0059486XI1Z0P98KP35") & (data["productID"] == "B000WE8JES")]
# Out:
#         reviewID  overall  verified  reviewTime            reviewerID  \
# 143178    143178        5      True  2014-06-07  A0059486XI1Z0P98KP35
# 143204    143204        5      True  2014-06-07  A0059486XI1Z0P98KP35
#
#          productID                                         reviewText  \
# 143178  B000WE8JES  If you're like me and happen to run out of spa...
# 143204  B000WE8JES  If you're like me and happen to run out of spa...
#
#                                         summary vote style  \
# 143178  Great choice, you won't be disappointed    0   NaN
# 143204  Great choice, you won't be disappointed    0   NaN
#
#                                                  category  \
# 143178  ['Video Games', 'Retro Gaming & Microconsoles'...
# 143204  ['Video Games', 'Retro Gaming & Microconsoles'...
#
#                                  title      brand  \
# 143178  Playstation 2 Memory Card 16MB  by Katana
# 143204  Playstation 2 Memory Card 16MB  by Katana
#
#                                                      rank     main_cat  \
# 143178  >#16,000 in Video Games (See Top 100 in Video ...  Video Games
# 143204  >#16,000 in Video Games (See Top 100 in Video ...  Video Games
#
#                                               description  \
# 143178  ["Katana's official Sony-licensed 16 MB Memory...
# 143204  ["Katana's official Sony-licensed 16 MB Memory...
#
#                                                  also_buy  \
# 143178  ['B000066TS5', 'B00004YRQ9', 'B0045L3SNQ', 'B0...
# 143204  ['B000066TS5', 'B00004YRQ9', 'B0045L3SNQ', 'B0...
#
#                                                 also_view  \
# 143178  ['B0792PXC9T', 'B0015DOL8I', 'B00006F2EP', 'B0...
# 143204  ['B0792PXC9T', 'B0015DOL8I', 'B00006F2EP', 'B0...
#
#                                                   feature  numberOfReviews
# 143178  ['16 MB Storage', 'Allows the user to save gam...               53
# 143204  ['16 MB Storage', 'Allows the user to save gam...               53

# %%
# Let's look at the matrix for user A0059486XI1Z0P98KP35, product B000WE8JES
ratings_matrix.loc["A0059486XI1Z0P98KP35", "B000WE8JES"]
# Out:
# 5

# %%
# Check unique combinations of user and product

# %% [markdown]
# ### Implementing Non-negative Matrix Factorization

# %%
# Convert matrix to array
R = np.array(ratings_matrix)

# %%
# Instantiate NMF with 4 components
nmf = NMF(n_components = 4, max_iter = 2000, random_state = 232323, verbose = 5)

# %%
# Find matrix with features
W = nmf.fit_transform(R)
# Out:
# violation: 1.0
# violation: 0.4383189547612514
# violation: 0.16048231225841422
# violation: 0.1171522333200848
# violation: 0.09651815126215055
# violation: 0.08350624760043215
# violation: 0.07309329943630058
# violation: 0.06380219437466543
# violation: 0.05509813433566676
# violation: 0.0469522428326789
# violation: 0.039498366108902075
# violation: 0.03274643956874198
# violation: 0.027025892710030596
# violation: 0.02221280501040572
# violation: 0.018192090933477862
# violation: 0.014874722340107682
# violation: 0.012164657498937045
# violation: 0.00995144143959776
# violation: 0.00815794217303045
# violation: 0.006710692145675376
# violation: 0.005542527784494082
# violation: 0.004600994639416332
# violation: 0.0038328722936516514
# violation: 0.0032046669937021185
# violation: 0.0026901726384994003
# violation: 0.002267496855306264
# violation: 0.0019196500299080883
# violation: 0.0016334464723922152
# violation: 0.001397839567040678
# violation: 0.0012036428552340875
# violation: 0.00104340278060873
# violation: 0.0009110187138908943
# violation: 0.0008016274025050182
# violation: 0.0007118188094158004
# violation: 0.0006386394575278886
# violation: 0.000579644982942526
# violation: 0.0005322639629595547
# violation: 0.0004945436685964623
# violation: 0.00046455598227690143
# violation: 0.000440373515624153
# violation: 0.0004210675190047029
# violation: 0.0004054352052090484
# violation: 0.00039207779716121535
# violation: 0.00038025449618715273
# violation: 0.0003696891387982417
# violation: 0.00036040729959481037
# violation: 0.0003523813238685203
# violation: 0.0003449459245900583
# violation: 0.0003377408828216312
# violation: 0.0003306722164001936
# violation: 0.00032372969543844915
# violation: 0.00031690647247694276
# violation: 0.00031021443455656023
# violation: 0.000303633639347729
# violation: 0.00029719285299801277
# violation: 0.000290870153341802
# violation: 0.0002846680322357261
# violation: 0.0002785760951465988
# violation: 0.00027260112344369784
# violation: 0.0002667647136657932
# violation: 0.0002610706188122135
# violation: 0.00025551325301071006
# violation: 0.0002500600041826023
# violation: 0.00024473314965349035
# violation: 0.00023953050758738372
# violation: 0.00023443307076833134
# violation: 0.00022946048112454284
# violation: 0.00022460663118423148
# violation: 0.00021985895381167653
# violation: 0.0002152119445210908
# violation: 0.00021066369558313852
# violation: 0.0002061985788027785
# violation: 0.00020181093709794505
# violation: 0.0001975267067011163
# violation: 0.0001933365873732055
# violation: 0.0001892255549217339
# violation: 0.00018518483616262581
# violation: 0.00018125147013305757
# violation: 0.00017740705674901158
# violation: 0.0001736438426158741
# violation: 0.00016995494198800381
# violation: 0.00016635070602394046
# violation: 0.00016281876240916066
# violation: 0.0001593649222523045
# violation: 0.0001559916926619383
# violation: 0.00015268964995798418
# violation: 0.0001494615287069156
# violation: 0.00014630385066232823
# violation: 0.00014321080774824398
# violation: 0.0001401840818162439
# violation: 0.00013721595342093643
# violation: 0.00013431546597971342
# violation: 0.00013147558080764255
# violation: 0.00012869340772150725
# violation: 0.00012596557874613122
# violation: 0.0001232992319794862
# violation: 0.00012068759719054218
# violation: 0.00011813407956100154
# violation: 0.00011564465598291852
# violation: 0.00011319975210974717
# violation: 0.00011081059912338863
# violation: 0.00010847132548820843
# violation: 0.0001061708256032803
# violation: 0.00010392481615335175
# violation: 0.0001017283044687149
# violation: 9.958110653136512e-05
# Converged at iteration 106

# %%
# Explore shape of Feature Matrix (rows = users, columns = features)
W.shape
# Out:
# (55223, 4)

# %%
# Explore first rows of Feature Matrix
W[:5]
# Out:
# array([[0.0026341 , 0.00358641, 0.00070855, 0.00416665],
#        [0.        , 0.0339253 , 0.        , 0.03151454],
#        [0.00302407, 0.01389829, 0.        , 0.01052313],
#        [0.04617359, 0.        , 0.00074319, 0.0729523 ],
#        [0.06926943, 0.        , 0.0018468 , 0.00072501]])

# %%
# Construct Coefficient Matrix ( V = W * H)
H = nmf.components_

# %%
# Explore shape of Coefficient Matrix (rows = feaures, columns = products)
H.shape
# Out:
# (4, 17408)

# %%
# Reconstruction error
print(nmf.reconstruction_err_)
# Out:
# 2998.448380876802

# %% [markdown]
# ## Recommending based on NMF

# %%
# Reconstruct the matrix by computing dot product between Feature Matrix (W) and Coefficient Matrix (H)
predictions = np.dot(W, H)

# %%
# Convert to df
predictions_df = pd.DataFrame(predictions, columns = ratings_matrix.columns)
predictions_df.index = ratings_matrix.index

# %%
# Explore resulting df
print(predictions_df.shape)
predictions_df.head()
# Out:
# (55223, 17408)
# productID             0700026398  0700026657  0700099867  0804161380  \
# reviewerID
# A0059486XI1Z0P98KP35    0.000118    0.000114    0.000093    0.000761
# A0220159ZRNBTRKLG08H    0.000419    0.000673    0.000287    0.006049
# A0266076X6KPZ6CCHGVS    0.000212    0.000315    0.000189    0.002132
# A0277912HT4JSJKVSL3E    0.002068    0.000908    0.001087    0.010584
# A02836981FYG9912C66F    0.001656    0.001064    0.001631    0.000105
#
# productID               3828770193  6050036071  7293000936  7544256944  \
# reviewerID
# A0059486XI1Z0P98KP35  8.571009e-06    0.000130    0.000049    0.000094
# A0220159ZRNBTRKLG08H  7.845146e-05    0.001078    0.000422    0.000708
# A0266076X6KPZ6CCHGVS  3.134602e-05    0.000398    0.000162    0.000236
# A0277912HT4JSJKVSL3E  2.424416e-05    0.001323    0.000338    0.001638
# A02836981FYG9912C66F  2.409425e-07    0.000015    0.000003    0.000016
#
# productID             8176503290  8565000168  ...  B01HD1B76O  B01HD2TECW  \
# reviewerID                                    ...
# A0059486XI1Z0P98KP35    0.000011    0.000011  ...    0.000006    0.000050
# A0220159ZRNBTRKLG08H    0.000089    0.000100  ...    0.000019    0.000163
# A0266076X6KPZ6CCHGVS    0.000036    0.000040  ...    0.000010    0.000087
# A0277912HT4JSJKVSL3E    0.000050    0.000048  ...    0.000096    0.000870
# A02836981FYG9912C66F    0.000023    0.000006  ...    0.000078    0.000745
#
# productID             B01HDJFJKG  B01HDJFJLK  B01HDJFJOM  B01HFRICLE  \
# reviewerID
# A0059486XI1Z0P98KP35    0.000042    0.000142    0.000054    0.000158
# A0220159ZRNBTRKLG08H    0.000216    0.000000    0.000128    0.001035
# A0266076X6KPZ6CCHGVS    0.000089    0.000163    0.000074    0.000369
# A0277912HT4JSJKVSL3E    0.000717    0.002496    0.000785    0.002758
# A02836981FYG9912C66F    0.000362    0.003744    0.000745    0.000568
#
# productID             B01HGPUTCA  B01HH6JEOC  B01HIZF7XE  B01HIZGKOE
# reviewerID
# A0059486XI1Z0P98KP35    0.000017    0.000104    0.000531    0.000029
# A0220159ZRNBTRKLG08H    0.000062    0.000499    0.002027    0.000055
# A0266076X6KPZ6CCHGVS    0.000031    0.000210    0.000992    0.000050
# A0277912HT4JSJKVSL3E    0.000299    0.001820    0.009077    0.000410
# A02836981FYG9912C66F    0.000233    0.001010    0.007047    0.000615
#
# [5 rows x 17408 columns]

# %% [markdown]
# We would recommend products to users with a high predicted rating
